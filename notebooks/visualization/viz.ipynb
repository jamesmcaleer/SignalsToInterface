# %% [markdown]
# # Visualizing time-series EEG data with matplotlib
# Hi again, my name is James and I'm a CS student at Binghamton University.
# <br>
# The goal of this entire ML and BCI blog is to build a strong foundation in statistics, machine learning, and signal processing so that I can apply it to brain-computer-interface (BCI) research.
#
# <br>
# Last time we learned how to store EEG data channel into a pandas DataFrame. After sorting, filtering, and eventually normalizing the values in each channel, I think it is a good idea to make some visual representations of this data.
#
# <br>
# For anyone who does not know, pandas is a Python library made for holding data similar to the way an Excel spreadsheet does. It comes with many data science and statistics functions to make sense of data.
# <br>
# Matplotlib is a Python library made to visualize data with many built tools such as scatter plots, bar charts, histograms, and _many_ others.
#
# <br>
# So today I will be learning how to use matplotlib with pandas. Here is my plan:
# - Take the normalized data from last my last notebook: _Reading, Sorting, and Normalizing EEG data with Pandas_
# - something ab the 255 hz
#
# As always, _please_ email me if you have any questions or see any mistakes in either my code or commentary (jamesmcaleer717@gmail.com)

# %%
pip install pandas

# %%
pip install matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/Users/jmac/Programming/BCI/2025/blog/notebooks/visualization/openbci-sample.txt', delimiter=',', comment='%')

# %%
chans = ["Sample Index"]
for i in range(8):
    chans.append(f" EXG Channel {i}")

new_df = df[chans]

# %%
# Out:
#        Sample Index   EXG Channel 0   EXG Channel 1   EXG Channel 2  \
# 0                 0        61379.36        49492.89       -16597.06
# 1                 1        60973.46        48972.47       -16279.02
# 2                 2        61433.45        49486.27       -16245.72
# 3                 3        61788.96        49917.57       -16488.30
# 4                 4        61512.69        49619.42       -16606.27
# ...             ...             ...             ...             ...
# 22485           213        58750.42        47034.95       -18637.04
# 22486           214        59029.14        47391.53       -18737.73
# 22487           215        58890.72        47196.80       -18850.75
# 22488           216        58567.63        46769.70       -18777.12
# 22489           217        58705.56        46972.84       -18624.12
#
#         EXG Channel 3   EXG Channel 4   EXG Channel 5   EXG Channel 6  \
# 0           -21309.75         6703.91        -3284.86         7223.10
# ...
